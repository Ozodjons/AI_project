# %% [markdown]
# ### The Boston Housing dataset is included in Keras, so it is simple to access using keras.datasets.boston_housing. We standardize both the training and test data by using the mean and standard deviation from the training data. The parameter axis=0 ensures that we compute the mean and standard deviation for each input variable separately. The resulting mean (and standard deviation) is a vector of means instead of a single value. That is, the standardized value of the nitric oxides concentration is not affected by the values of the per capita crime rate or any of the other variables.

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
import logging
tf.get_logger().setLevel(logging.ERROR)

EPOCHS=500
BATCH_SIZE=16

# Read asn standardize the data
boston_housing=keras.datasets.boston_housing
(raw_x_train, y_train), (raw_x_test, y_test)=boston_housing.load_data()
x_mean=np.mean(raw_x_train, axis=0)
x_stddev=np.std(raw_x_train, axis=0)
x_train=(raw_x_train - x_mean) / x_stddev
x_test=(raw_x_test - x_mean) / x_stddev
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57026/57026 [==============================] - 0s 0us/step

# %% [markdown]
# ### There, the layers were passed as parameters to the constructor of the model. A different way of doing it is to first instantiate the model object without any layers, and then add them one by one using the member method add(). As long as we work with relatively few layers, the approach taken just depends on user preference, but for deep models with tens of layers, the code typically gets more readable and maintainable by adding the layers one by one. One example of this is a deep model of identical layers where the layers can be added to the model with a for loop, which makes for a much more compact model description.

# %%
# Create and train model
model=Sequential()
model.add(Dense(64, activation='relu', input_shape=[13]))
model.add(Dense(64, activation='relu')) # We are doing DL!
model.add(Dense(1, activation='linear'))
model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])
model.summary()
history=model.fit(x_train, y_train, validation_data=(x_test, y_test), epochs=EPOCHS, batch_size=BATCH_SIZE, verbose=2, shuffle=True)
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_3 (Dense)             (None, 64)                896
#
#  dense_4 (Dense)             (None, 64)                4160
#
#  dense_5 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 5,121
# Trainable params: 5,121
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/500
# 26/26 - 1s - loss: 536.6336 - mean_absolute_error: 21.2202 - val_loss: 499.3687 - val_mean_absolute_error: 20.3818 - 1s/epoch - 40ms/step
# Epoch 2/500
# 26/26 - 0s - loss: 402.4184 - mean_absolute_error: 17.8109 - val_loss: 315.4975 - val_mean_absolute_error: 15.5896 - 88ms/epoch - 3ms/step
# Epoch 3/500
# 26/26 - 0s - loss: 206.4786 - mean_absolute_error: 11.8137 - val_loss: 120.6178 - val_mean_absolute_error: 9.1238 - 88ms/epoch - 3ms/step
# Epoch 4/500
# 26/26 - 0s - loss: 79.4026 - mean_absolute_error: 6.8481 - val_loss: 68.3301 - val_mean_absolute_error: 6.5151 - 89ms/epoch - 3ms/step
# Epoch 5/500
# 26/26 - 0s - loss: 49.2789 - mean_absolute_error: 5.2348 - val_loss: 45.6677 - val_mean_absolute_error: 5.3893 - 79ms/epoch - 3ms/step
# Epoch 6/500
# 26/26 - 0s - loss: 33.7638 - mean_absolute_error: 4.2147 - val_loss: 35.2716 - val_mean_absolute_error: 4.7766 - 79ms/epoch - 3ms/step
# Epoch 7/500
# 26/26 - 0s - loss: 27.9290 - mean_absolute_error: 3.7740 - val_loss: 30.4574 - val_mean_absolute_error: 4.4434 - 81ms/epoch - 3ms/step
# Epoch 8/500
# 26/26 - 0s - loss: 24.1616 - mean_absolute_error: 3.4789 - val_loss: 27.1623 - val_mean_absolute_error: 4.1106 - 89ms/epoch - 3ms/step
# Epoch 9/500
# 26/26 - 0s - loss: 21.6731 - mean_absolute_error: 3.2924 - val_loss: 25.4818 - val_mean_absolute_error: 3.9027 - 77ms/epoch - 3ms/step
# Epoch 10/500
# 26/26 - 0s - loss: 19.5330 - mean_absolute_error: 3.0997 - val_loss: 23.4511 - val_mean_absolute_error: 3.6899 - 86ms/epoch - 3ms/step
# Epoch 11/500
# 26/26 - 0s - loss: 17.9192 - mean_absolute_error: 2.9840 - val_loss: 22.8074 - val_mean_absolute_error: 3.5956 - 91ms/epoch - 3ms/step
# Epoch 12/500
# 26/26 - 0s - loss: 16.6815 - mean_absolute_error: 2.8569 - val_loss: 22.7091 - val_mean_absolute_error: 3.5618 - 97ms/epoch - 4ms/step
# Epoch 13/500
# 26/26 - 0s - loss: 16.0086 - mean_absolute_error: 2.8602 - val_loss: 22.3823 - val_mean_absolute_error: 3.4891 - 87ms/epoch - 3ms/step
# Epoch 14/500
# 26/26 - 0s - loss: 14.8971 - mean_absolute_error: 2.7110 - val_loss: 22.3563 - val_mean_absolute_error: 3.4426 - 89ms/epoch - 3ms/step
# Epoch 15/500
# 26/26 - 0s - loss: 14.1069 - mean_absolute_error: 2.6609 - val_loss: 22.1404 - val_mean_absolute_error: 3.4192 - 85ms/epoch - 3ms/step
# Epoch 16/500
# 26/26 - 0s - loss: 13.3089 - mean_absolute_error: 2.5813 - val_loss: 21.6919 - val_mean_absolute_error: 3.3505 - 92ms/epoch - 4ms/step
# Epoch 17/500
# 26/26 - 0s - loss: 13.0513 - mean_absolute_error: 2.5446 - val_loss: 21.6097 - val_mean_absolute_error: 3.3196 - 85ms/epoch - 3ms/step
# Epoch 18/500
# 26/26 - 0s - loss: 12.3370 - mean_absolute_error: 2.5106 - val_loss: 21.2126 - val_mean_absolute_error: 3.2418 - 87ms/epoch - 3ms/step
# Epoch 19/500
# 26/26 - 0s - loss: 12.0306 - mean_absolute_error: 2.4268 - val_loss: 21.3188 - val_mean_absolute_error: 3.2732 - 83ms/epoch - 3ms/step
# Epoch 20/500
# 26/26 - 0s - loss: 11.5603 - mean_absolute_error: 2.4170 - val_loss: 21.5468 - val_mean_absolute_error: 3.2475 - 88ms/epoch - 3ms/step
# Epoch 21/500
# 26/26 - 0s - loss: 11.2282 - mean_absolute_error: 2.4119 - val_loss: 21.6891 - val_mean_absolute_error: 3.2484 - 93ms/epoch - 4ms/step
# Epoch 22/500
# 26/26 - 0s - loss: 10.9672 - mean_absolute_error: 2.3356 - val_loss: 21.6153 - val_mean_absolute_error: 3.2047 - 99ms/epoch - 4ms/step
# Epoch 23/500
# 26/26 - 0s - loss: 10.8651 - mean_absolute_error: 2.3752 - val_loss: 21.3307 - val_mean_absolute_error: 3.1353 - 88ms/epoch - 3ms/step
# Epoch 24/500
# 26/26 - 0s - loss: 10.4842 - mean_absolute_error: 2.2980 - val_loss: 21.2140 - val_mean_absolute_error: 3.1639 - 88ms/epoch - 3ms/step
# Epoch 25/500
# 26/26 - 0s - loss: 10.1861 - mean_absolute_error: 2.2807 - val_loss: 20.8364 - val_mean_absolute_error: 3.1622 - 92ms/epoch - 4ms/step
# Epoch 26/500
# 26/26 - 0s - loss: 10.1001 - mean_absolute_error: 2.2465 - val_loss: 21.5890 - val_mean_absolute_error: 3.1074 - 82ms/epoch - 3ms/step
# Epoch 27/500
# 26/26 - 0s - loss: 9.8138 - mean_absolute_error: 2.2495 - val_loss: 21.4681 - val_mean_absolute_error: 3.1386 - 92ms/epoch - 4ms/step
# Epoch 28/500
# 26/26 - 0s - loss: 9.6230 - mean_absolute_error: 2.2209 - val_loss: 21.3840 - val_mean_absolute_error: 3.1135 - 91ms/epoch - 4ms/step
# Epoch 29/500
# 26/26 - 0s - loss: 9.4376 - mean_absolute_error: 2.1959 - val_loss: 21.2267 - val_mean_absolute_error: 3.0279 - 82ms/epoch - 3ms/step
# Epoch 30/500
# 26/26 - 0s - loss: 9.3120 - mean_absolute_error: 2.1887 - val_loss: 20.9211 - val_mean_absolute_error: 3.0091 - 104ms/epoch - 4ms/step
# Epoch 31/500
# 26/26 - 0s - loss: 9.2496 - mean_absolute_error: 2.1485 - val_loss: 21.7219 - val_mean_absolute_error: 3.0355 - 78ms/epoch - 3ms/step
# Epoch 32/500
# 26/26 - 0s - loss: 9.1123 - mean_absolute_error: 2.1895 - val_loss: 21.9832 - val_mean_absolute_error: 3.1001 - 121ms/epoch - 5ms/step
# Epoch 33/500
# 26/26 - 0s - loss: 8.9735 - mean_absolute_error: 2.1366 - val_loss: 20.7276 - val_mean_absolute_error: 2.9306 - 308ms/epoch - 12ms/step
# Epoch 34/500
# 26/26 - 0s - loss: 8.8563 - mean_absolute_error: 2.1283 - val_loss: 20.6767 - val_mean_absolute_error: 3.0599 - 179ms/epoch - 7ms/step
# Epoch 35/500
# 26/26 - 0s - loss: 8.7967 - mean_absolute_error: 2.1093 - val_loss: 21.3878 - val_mean_absolute_error: 2.9979 - 151ms/epoch - 6ms/step
# Epoch 36/500
# 26/26 - 0s - loss: 8.5743 - mean_absolute_error: 2.0923 - val_loss: 20.9399 - val_mean_absolute_error: 2.9593 - 90ms/epoch - 3ms/step
# Epoch 37/500
# 26/26 - 0s - loss: 8.5051 - mean_absolute_error: 2.0658 - val_loss: 22.2836 - val_mean_absolute_error: 3.0581 - 102ms/epoch - 4ms/step
# Epoch 38/500
# 26/26 - 0s - loss: 8.5605 - mean_absolute_error: 2.1183 - val_loss: 21.1440 - val_mean_absolute_error: 2.9729 - 75ms/epoch - 3ms/step
# Epoch 39/500
# 26/26 - 0s - loss: 8.2238 - mean_absolute_error: 2.0388 - val_loss: 20.6707 - val_mean_absolute_error: 2.9049 - 77ms/epoch - 3ms/step
# Epoch 40/500
# 26/26 - 0s - loss: 8.2140 - mean_absolute_error: 2.0669 - val_loss: 21.4634 - val_mean_absolute_error: 2.9611 - 164ms/epoch - 6ms/step
# Epoch 41/500
# 26/26 - 0s - loss: 8.0781 - mean_absolute_error: 2.0236 - val_loss: 20.7184 - val_mean_absolute_error: 2.8671 - 269ms/epoch - 10ms/step
# Epoch 42/500
# 26/26 - 0s - loss: 7.9347 - mean_absolute_error: 2.0106 - val_loss: 21.4122 - val_mean_absolute_error: 2.9386 - 205ms/epoch - 8ms/step
# Epoch 43/500
# 26/26 - 0s - loss: 8.3656 - mean_absolute_error: 2.0610 - val_loss: 20.8259 - val_mean_absolute_error: 2.8652 - 95ms/epoch - 4ms/step
# Epoch 44/500
# 26/26 - 0s - loss: 8.0646 - mean_absolute_error: 2.0385 - val_loss: 22.1121 - val_mean_absolute_error: 3.0394 - 92ms/epoch - 4ms/step
# Epoch 45/500
# 26/26 - 0s - loss: 7.8804 - mean_absolute_error: 2.0016 - val_loss: 21.3200 - val_mean_absolute_error: 2.9696 - 88ms/epoch - 3ms/step
# Epoch 46/500
# 26/26 - 0s - loss: 7.6935 - mean_absolute_error: 1.9847 - val_loss: 21.8269 - val_mean_absolute_error: 2.9215 - 74ms/epoch - 3ms/step
# Epoch 47/500
# 26/26 - 0s - loss: 7.5731 - mean_absolute_error: 1.9781 - val_loss: 20.2416 - val_mean_absolute_error: 2.7746 - 93ms/epoch - 4ms/step
# Epoch 48/500
# 26/26 - 0s - loss: 7.7413 - mean_absolute_error: 2.0100 - val_loss: 19.8422 - val_mean_absolute_error: 2.8190 - 79ms/epoch - 3ms/step
# Epoch 49/500
# 26/26 - 0s - loss: 7.6543 - mean_absolute_error: 1.9689 - val_loss: 21.7264 - val_mean_absolute_error: 2.9666 - 100ms/epoch - 4ms/step
# Epoch 50/500
# 26/26 - 0s - loss: 7.6868 - mean_absolute_error: 1.9939 - val_loss: 20.3793 - val_mean_absolute_error: 2.7958 - 95ms/epoch - 4ms/step
# Epoch 51/500
# 26/26 - 0s - loss: 7.4386 - mean_absolute_error: 1.9499 - val_loss: 21.1286 - val_mean_absolute_error: 2.8532 - 97ms/epoch - 4ms/step
# Epoch 52/500
# 26/26 - 0s - loss: 7.2141 - mean_absolute_error: 1.9120 - val_loss: 20.0447 - val_mean_absolute_error: 2.8645 - 80ms/epoch - 3ms/step
# Epoch 53/500
# 26/26 - 0s - loss: 7.3198 - mean_absolute_error: 1.9262 - val_loss: 20.0031 - val_mean_absolute_error: 2.8364 - 89ms/epoch - 3ms/step
# Epoch 54/500
# 26/26 - 0s - loss: 7.2397 - mean_absolute_error: 1.9510 - val_loss: 19.4143 - val_mean_absolute_error: 2.8469 - 86ms/epoch - 3ms/step
# Epoch 55/500
# 26/26 - 0s - loss: 7.2877 - mean_absolute_error: 1.9262 - val_loss: 20.4621 - val_mean_absolute_error: 2.8624 - 80ms/epoch - 3ms/step
# Epoch 56/500
# 26/26 - 0s - loss: 6.9748 - mean_absolute_error: 1.8954 - val_loss: 20.0578 - val_mean_absolute_error: 2.7829 - 88ms/epoch - 3ms/step
# Epoch 57/500
# 26/26 - 0s - loss: 7.1356 - mean_absolute_error: 1.8889 - val_loss: 20.1481 - val_mean_absolute_error: 2.8033 - 87ms/epoch - 3ms/step
# Epoch 58/500
# 26/26 - 0s - loss: 7.2440 - mean_absolute_error: 1.9250 - val_loss: 20.0708 - val_mean_absolute_error: 2.7558 - 82ms/epoch - 3ms/step
# Epoch 59/500
# 26/26 - 0s - loss: 7.2348 - mean_absolute_error: 1.9352 - val_loss: 18.4743 - val_mean_absolute_error: 2.6558 - 89ms/epoch - 3ms/step
# Epoch 60/500
# 26/26 - 0s - loss: 6.7350 - mean_absolute_error: 1.8622 - val_loss: 19.4012 - val_mean_absolute_error: 2.7854 - 80ms/epoch - 3ms/step
# Epoch 61/500
# 26/26 - 0s - loss: 6.8994 - mean_absolute_error: 1.8703 - val_loss: 18.9238 - val_mean_absolute_error: 2.7373 - 78ms/epoch - 3ms/step
# Epoch 62/500
# 26/26 - 0s - loss: 6.9424 - mean_absolute_error: 1.8765 - val_loss: 18.8202 - val_mean_absolute_error: 2.6848 - 87ms/epoch - 3ms/step
# Epoch 63/500
# 26/26 - 0s - loss: 6.6790 - mean_absolute_error: 1.8183 - val_loss: 19.3925 - val_mean_absolute_error: 2.7239 - 77ms/epoch - 3ms/step
# Epoch 64/500
# 26/26 - 0s - loss: 6.6741 - mean_absolute_error: 1.8570 - val_loss: 19.1138 - val_mean_absolute_error: 2.6456 - 77ms/epoch - 3ms/step
# Epoch 65/500
# 26/26 - 0s - loss: 6.6023 - mean_absolute_error: 1.8422 - val_loss: 19.2662 - val_mean_absolute_error: 2.6841 - 89ms/epoch - 3ms/step
# Epoch 66/500
# 26/26 - 0s - loss: 6.4976 - mean_absolute_error: 1.8147 - val_loss: 19.5542 - val_mean_absolute_error: 2.7235 - 82ms/epoch - 3ms/step
# Epoch 67/500
# 26/26 - 0s - loss: 6.6767 - mean_absolute_error: 1.8261 - val_loss: 19.3963 - val_mean_absolute_error: 2.7595 - 93ms/epoch - 4ms/step
# Epoch 68/500
# 26/26 - 0s - loss: 6.5156 - mean_absolute_error: 1.8300 - val_loss: 19.0296 - val_mean_absolute_error: 2.6623 - 74ms/epoch - 3ms/step
# Epoch 69/500
# 26/26 - 0s - loss: 6.4645 - mean_absolute_error: 1.8769 - val_loss: 18.5370 - val_mean_absolute_error: 2.7884 - 91ms/epoch - 3ms/step
# Epoch 70/500
# 26/26 - 0s - loss: 6.3856 - mean_absolute_error: 1.8049 - val_loss: 18.1598 - val_mean_absolute_error: 2.6239 - 90ms/epoch - 3ms/step
# Epoch 71/500
# 26/26 - 0s - loss: 6.3406 - mean_absolute_error: 1.7761 - val_loss: 18.7877 - val_mean_absolute_error: 2.7127 - 96ms/epoch - 4ms/step
# Epoch 72/500
# 26/26 - 0s - loss: 6.2571 - mean_absolute_error: 1.7987 - val_loss: 18.1796 - val_mean_absolute_error: 2.6804 - 79ms/epoch - 3ms/step
# Epoch 73/500
# 26/26 - 0s - loss: 6.2473 - mean_absolute_error: 1.7910 - val_loss: 18.4581 - val_mean_absolute_error: 2.6452 - 90ms/epoch - 3ms/step
# Epoch 74/500
# 26/26 - 0s - loss: 6.0376 - mean_absolute_error: 1.7533 - val_loss: 18.5287 - val_mean_absolute_error: 2.7064 - 92ms/epoch - 4ms/step
# Epoch 75/500
# 26/26 - 0s - loss: 6.2374 - mean_absolute_error: 1.7802 - val_loss: 19.8385 - val_mean_absolute_error: 2.8959 - 82ms/epoch - 3ms/step
# Epoch 76/500
# 26/26 - 0s - loss: 6.3445 - mean_absolute_error: 1.8141 - val_loss: 18.6138 - val_mean_absolute_error: 2.7011 - 83ms/epoch - 3ms/step
# Epoch 77/500
# 26/26 - 0s - loss: 6.1304 - mean_absolute_error: 1.7811 - val_loss: 17.3882 - val_mean_absolute_error: 2.5650 - 97ms/epoch - 4ms/step
# Epoch 78/500
# 26/26 - 0s - loss: 6.0124 - mean_absolute_error: 1.7629 - val_loss: 17.3077 - val_mean_absolute_error: 2.5487 - 94ms/epoch - 4ms/step
# Epoch 79/500
# 26/26 - 0s - loss: 6.1104 - mean_absolute_error: 1.7956 - val_loss: 17.7431 - val_mean_absolute_error: 2.6212 - 86ms/epoch - 3ms/step
# Epoch 80/500
# 26/26 - 0s - loss: 5.8812 - mean_absolute_error: 1.7326 - val_loss: 17.0568 - val_mean_absolute_error: 2.5426 - 84ms/epoch - 3ms/step
# Epoch 81/500
# 26/26 - 0s - loss: 6.0109 - mean_absolute_error: 1.7514 - val_loss: 17.1488 - val_mean_absolute_error: 2.5512 - 82ms/epoch - 3ms/step
# Epoch 82/500
# 26/26 - 0s - loss: 5.9025 - mean_absolute_error: 1.7418 - val_loss: 17.2113 - val_mean_absolute_error: 2.5226 - 101ms/epoch - 4ms/step
# Epoch 83/500
# 26/26 - 0s - loss: 5.8803 - mean_absolute_error: 1.7311 - val_loss: 18.3034 - val_mean_absolute_error: 2.6935 - 79ms/epoch - 3ms/step
# Epoch 84/500
# 26/26 - 0s - loss: 5.6924 - mean_absolute_error: 1.7053 - val_loss: 18.4663 - val_mean_absolute_error: 2.7434 - 90ms/epoch - 3ms/step
# Epoch 85/500
# 26/26 - 0s - loss: 5.7846 - mean_absolute_error: 1.7297 - val_loss: 17.5747 - val_mean_absolute_error: 2.6355 - 87ms/epoch - 3ms/step
# Epoch 86/500
# 26/26 - 0s - loss: 5.5858 - mean_absolute_error: 1.6815 - val_loss: 18.2793 - val_mean_absolute_error: 2.6252 - 74ms/epoch - 3ms/step
# Epoch 87/500
# 26/26 - 0s - loss: 5.4679 - mean_absolute_error: 1.6885 - val_loss: 17.6783 - val_mean_absolute_error: 2.6944 - 81ms/epoch - 3ms/step
# Epoch 88/500
# 26/26 - 0s - loss: 5.5522 - mean_absolute_error: 1.6715 - val_loss: 17.7278 - val_mean_absolute_error: 2.6104 - 81ms/epoch - 3ms/step
# Epoch 89/500
# 26/26 - 0s - loss: 5.5634 - mean_absolute_error: 1.6722 - val_loss: 17.7268 - val_mean_absolute_error: 2.6736 - 88ms/epoch - 3ms/step
# Epoch 90/500
# 26/26 - 0s - loss: 5.4684 - mean_absolute_error: 1.6618 - val_loss: 18.0522 - val_mean_absolute_error: 2.7223 - 93ms/epoch - 4ms/step
# Epoch 91/500
# 26/26 - 0s - loss: 5.5743 - mean_absolute_error: 1.7015 - val_loss: 18.8701 - val_mean_absolute_error: 2.8064 - 91ms/epoch - 3ms/step
# Epoch 92/500
# 26/26 - 0s - loss: 5.5119 - mean_absolute_error: 1.6844 - val_loss: 17.2707 - val_mean_absolute_error: 2.5925 - 82ms/epoch - 3ms/step
# Epoch 93/500
# 26/26 - 0s - loss: 5.3515 - mean_absolute_error: 1.6419 - val_loss: 17.0783 - val_mean_absolute_error: 2.5546 - 80ms/epoch - 3ms/step
# Epoch 94/500
# 26/26 - 0s - loss: 5.3157 - mean_absolute_error: 1.6485 - val_loss: 16.6457 - val_mean_absolute_error: 2.5273 - 86ms/epoch - 3ms/step
# Epoch 95/500
# 26/26 - 0s - loss: 5.2668 - mean_absolute_error: 1.6330 - val_loss: 17.7077 - val_mean_absolute_error: 2.6084 - 92ms/epoch - 4ms/step
# Epoch 96/500
# 26/26 - 0s - loss: 5.2748 - mean_absolute_error: 1.6481 - val_loss: 17.0367 - val_mean_absolute_error: 2.5449 - 78ms/epoch - 3ms/step
# Epoch 97/500
# 26/26 - 0s - loss: 5.4274 - mean_absolute_error: 1.6707 - val_loss: 17.0007 - val_mean_absolute_error: 2.5269 - 79ms/epoch - 3ms/step
# Epoch 98/500
# 26/26 - 0s - loss: 5.0938 - mean_absolute_error: 1.5962 - val_loss: 17.1973 - val_mean_absolute_error: 2.5983 - 95ms/epoch - 4ms/step
# Epoch 99/500
# 26/26 - 0s - loss: 5.1301 - mean_absolute_error: 1.6180 - val_loss: 16.4705 - val_mean_absolute_error: 2.5580 - 91ms/epoch - 4ms/step
# Epoch 100/500
# 26/26 - 0s - loss: 5.2269 - mean_absolute_error: 1.6228 - val_loss: 17.2800 - val_mean_absolute_error: 2.5931 - 91ms/epoch - 3ms/step
# Epoch 101/500
# 26/26 - 0s - loss: 5.1430 - mean_absolute_error: 1.5972 - val_loss: 16.2488 - val_mean_absolute_error: 2.5246 - 77ms/epoch - 3ms/step
# Epoch 102/500
# 26/26 - 0s - loss: 5.0428 - mean_absolute_error: 1.6024 - val_loss: 16.4790 - val_mean_absolute_error: 2.5577 - 81ms/epoch - 3ms/step
# Epoch 103/500
# 26/26 - 0s - loss: 5.0623 - mean_absolute_error: 1.5978 - val_loss: 16.5472 - val_mean_absolute_error: 2.5222 - 95ms/epoch - 4ms/step
# Epoch 104/500
# 26/26 - 0s - loss: 5.1575 - mean_absolute_error: 1.6121 - val_loss: 16.5834 - val_mean_absolute_error: 2.5614 - 83ms/epoch - 3ms/step
# Epoch 105/500
# 26/26 - 0s - loss: 5.0093 - mean_absolute_error: 1.5961 - val_loss: 17.0967 - val_mean_absolute_error: 2.6888 - 76ms/epoch - 3ms/step
# Epoch 106/500
# 26/26 - 0s - loss: 5.0816 - mean_absolute_error: 1.6205 - val_loss: 17.4280 - val_mean_absolute_error: 2.6136 - 80ms/epoch - 3ms/step
# Epoch 107/500
# 26/26 - 0s - loss: 5.1307 - mean_absolute_error: 1.6148 - val_loss: 16.7945 - val_mean_absolute_error: 2.6104 - 76ms/epoch - 3ms/step
# Epoch 108/500
# 26/26 - 0s - loss: 5.0695 - mean_absolute_error: 1.5877 - val_loss: 17.4585 - val_mean_absolute_error: 2.6899 - 75ms/epoch - 3ms/step
# Epoch 109/500
# 26/26 - 0s - loss: 4.8744 - mean_absolute_error: 1.5715 - val_loss: 15.7992 - val_mean_absolute_error: 2.4880 - 90ms/epoch - 3ms/step
# Epoch 110/500
# 26/26 - 0s - loss: 4.8483 - mean_absolute_error: 1.5685 - val_loss: 16.0803 - val_mean_absolute_error: 2.5118 - 93ms/epoch - 4ms/step
# Epoch 111/500
# 26/26 - 0s - loss: 4.7500 - mean_absolute_error: 1.5644 - val_loss: 17.0556 - val_mean_absolute_error: 2.6107 - 86ms/epoch - 3ms/step
# Epoch 112/500
# 26/26 - 0s - loss: 4.8410 - mean_absolute_error: 1.5557 - val_loss: 15.6777 - val_mean_absolute_error: 2.4908 - 85ms/epoch - 3ms/step
# Epoch 113/500
# 26/26 - 0s - loss: 4.6591 - mean_absolute_error: 1.5343 - val_loss: 16.1054 - val_mean_absolute_error: 2.5374 - 83ms/epoch - 3ms/step
# Epoch 114/500
# 26/26 - 0s - loss: 4.7347 - mean_absolute_error: 1.5556 - val_loss: 16.5613 - val_mean_absolute_error: 2.6143 - 88ms/epoch - 3ms/step
# Epoch 115/500
# 26/26 - 0s - loss: 4.6413 - mean_absolute_error: 1.5325 - val_loss: 15.9496 - val_mean_absolute_error: 2.4971 - 96ms/epoch - 4ms/step
# Epoch 116/500
# 26/26 - 0s - loss: 4.7190 - mean_absolute_error: 1.5582 - val_loss: 15.4355 - val_mean_absolute_error: 2.4916 - 89ms/epoch - 3ms/step
# Epoch 117/500
# 26/26 - 0s - loss: 4.4776 - mean_absolute_error: 1.5085 - val_loss: 17.2095 - val_mean_absolute_error: 2.6370 - 102ms/epoch - 4ms/step
# Epoch 118/500
# 26/26 - 0s - loss: 5.1365 - mean_absolute_error: 1.6696 - val_loss: 15.5812 - val_mean_absolute_error: 2.4679 - 87ms/epoch - 3ms/step
# Epoch 119/500
# 26/26 - 0s - loss: 4.5080 - mean_absolute_error: 1.5174 - val_loss: 16.6483 - val_mean_absolute_error: 2.6112 - 87ms/epoch - 3ms/step
# Epoch 120/500
# 26/26 - 0s - loss: 4.7263 - mean_absolute_error: 1.5666 - val_loss: 15.3510 - val_mean_absolute_error: 2.4998 - 96ms/epoch - 4ms/step
# Epoch 121/500
# 26/26 - 0s - loss: 4.5014 - mean_absolute_error: 1.4999 - val_loss: 15.6167 - val_mean_absolute_error: 2.4872 - 79ms/epoch - 3ms/step
# Epoch 122/500
# 26/26 - 0s - loss: 4.4500 - mean_absolute_error: 1.4794 - val_loss: 15.2348 - val_mean_absolute_error: 2.4508 - 93ms/epoch - 4ms/step
# Epoch 123/500
# 26/26 - 0s - loss: 4.5921 - mean_absolute_error: 1.5301 - val_loss: 16.5543 - val_mean_absolute_error: 2.5896 - 97ms/epoch - 4ms/step
# Epoch 124/500
# 26/26 - 0s - loss: 4.6717 - mean_absolute_error: 1.5442 - val_loss: 16.6750 - val_mean_absolute_error: 2.6561 - 87ms/epoch - 3ms/step
# Epoch 125/500
# 26/26 - 0s - loss: 4.6881 - mean_absolute_error: 1.5704 - val_loss: 16.9569 - val_mean_absolute_error: 2.6940 - 91ms/epoch - 3ms/step
# Epoch 126/500
# 26/26 - 0s - loss: 4.7730 - mean_absolute_error: 1.5866 - val_loss: 15.9556 - val_mean_absolute_error: 2.5585 - 97ms/epoch - 4ms/step
# Epoch 127/500
# 26/26 - 0s - loss: 4.4180 - mean_absolute_error: 1.4839 - val_loss: 16.1712 - val_mean_absolute_error: 2.5722 - 85ms/epoch - 3ms/step
# Epoch 128/500
# 26/26 - 0s - loss: 4.3729 - mean_absolute_error: 1.4852 - val_loss: 15.3513 - val_mean_absolute_error: 2.4710 - 93ms/epoch - 4ms/step
# Epoch 129/500
# 26/26 - 0s - loss: 4.5592 - mean_absolute_error: 1.5673 - val_loss: 15.2747 - val_mean_absolute_error: 2.5158 - 76ms/epoch - 3ms/step
# Epoch 130/500
# 26/26 - 0s - loss: 4.2065 - mean_absolute_error: 1.4604 - val_loss: 15.2531 - val_mean_absolute_error: 2.4942 - 84ms/epoch - 3ms/step
# Epoch 131/500
# 26/26 - 0s - loss: 4.2769 - mean_absolute_error: 1.4600 - val_loss: 15.1848 - val_mean_absolute_error: 2.4831 - 75ms/epoch - 3ms/step
# Epoch 132/500
# 26/26 - 0s - loss: 4.1886 - mean_absolute_error: 1.4443 - val_loss: 15.4015 - val_mean_absolute_error: 2.5328 - 77ms/epoch - 3ms/step
# Epoch 133/500
# 26/26 - 0s - loss: 4.3595 - mean_absolute_error: 1.4599 - val_loss: 15.2088 - val_mean_absolute_error: 2.5208 - 80ms/epoch - 3ms/step
# Epoch 134/500
# 26/26 - 0s - loss: 4.4843 - mean_absolute_error: 1.4943 - val_loss: 15.2907 - val_mean_absolute_error: 2.5293 - 89ms/epoch - 3ms/step
# Epoch 135/500
# 26/26 - 0s - loss: 4.2571 - mean_absolute_error: 1.4459 - val_loss: 14.9107 - val_mean_absolute_error: 2.4794 - 75ms/epoch - 3ms/step
# Epoch 136/500
# 26/26 - 0s - loss: 4.3302 - mean_absolute_error: 1.4660 - val_loss: 15.4828 - val_mean_absolute_error: 2.5783 - 106ms/epoch - 4ms/step
# Epoch 137/500
# 26/26 - 0s - loss: 4.2076 - mean_absolute_error: 1.4478 - val_loss: 14.9207 - val_mean_absolute_error: 2.5065 - 92ms/epoch - 4ms/step
# Epoch 138/500
# 26/26 - 0s - loss: 4.1338 - mean_absolute_error: 1.4341 - val_loss: 15.2782 - val_mean_absolute_error: 2.5104 - 87ms/epoch - 3ms/step
# Epoch 139/500
# 26/26 - 0s - loss: 4.1545 - mean_absolute_error: 1.4529 - val_loss: 14.5685 - val_mean_absolute_error: 2.4261 - 94ms/epoch - 4ms/step
# Epoch 140/500
# 26/26 - 0s - loss: 4.1634 - mean_absolute_error: 1.4274 - val_loss: 14.8387 - val_mean_absolute_error: 2.4564 - 87ms/epoch - 3ms/step
# Epoch 141/500
# 26/26 - 0s - loss: 4.1371 - mean_absolute_error: 1.4528 - val_loss: 14.9612 - val_mean_absolute_error: 2.5283 - 80ms/epoch - 3ms/step
# Epoch 142/500
# 26/26 - 0s - loss: 3.9318 - mean_absolute_error: 1.4079 - val_loss: 14.8783 - val_mean_absolute_error: 2.4748 - 98ms/epoch - 4ms/step
# Epoch 143/500
# 26/26 - 0s - loss: 4.0138 - mean_absolute_error: 1.4149 - val_loss: 15.1072 - val_mean_absolute_error: 2.5209 - 81ms/epoch - 3ms/step
# Epoch 144/500
# 26/26 - 0s - loss: 4.0154 - mean_absolute_error: 1.4450 - val_loss: 14.0789 - val_mean_absolute_error: 2.4182 - 88ms/epoch - 3ms/step
# Epoch 145/500
# 26/26 - 0s - loss: 4.0097 - mean_absolute_error: 1.4245 - val_loss: 14.4477 - val_mean_absolute_error: 2.4862 - 83ms/epoch - 3ms/step
# Epoch 146/500
# 26/26 - 0s - loss: 3.8964 - mean_absolute_error: 1.4063 - val_loss: 14.8849 - val_mean_absolute_error: 2.5048 - 90ms/epoch - 3ms/step
# Epoch 147/500
# 26/26 - 0s - loss: 4.2072 - mean_absolute_error: 1.4343 - val_loss: 14.7185 - val_mean_absolute_error: 2.4447 - 95ms/epoch - 4ms/step
# Epoch 148/500
# 26/26 - 0s - loss: 4.1064 - mean_absolute_error: 1.4544 - val_loss: 14.5520 - val_mean_absolute_error: 2.4742 - 84ms/epoch - 3ms/step
# Epoch 149/500
# 26/26 - 0s - loss: 3.9550 - mean_absolute_error: 1.4046 - val_loss: 13.9742 - val_mean_absolute_error: 2.4548 - 101ms/epoch - 4ms/step
# Epoch 150/500
# 26/26 - 0s - loss: 3.8317 - mean_absolute_error: 1.3968 - val_loss: 15.2822 - val_mean_absolute_error: 2.6174 - 102ms/epoch - 4ms/step
# Epoch 151/500
# 26/26 - 0s - loss: 3.9367 - mean_absolute_error: 1.3982 - val_loss: 14.4725 - val_mean_absolute_error: 2.4624 - 92ms/epoch - 4ms/step
# Epoch 152/500
# 26/26 - 0s - loss: 3.9028 - mean_absolute_error: 1.4133 - val_loss: 15.3116 - val_mean_absolute_error: 2.5116 - 100ms/epoch - 4ms/step
# Epoch 153/500
# 26/26 - 0s - loss: 3.9697 - mean_absolute_error: 1.4340 - val_loss: 14.1521 - val_mean_absolute_error: 2.4267 - 98ms/epoch - 4ms/step
# Epoch 154/500
# 26/26 - 0s - loss: 3.8523 - mean_absolute_error: 1.3799 - val_loss: 14.2637 - val_mean_absolute_error: 2.4759 - 103ms/epoch - 4ms/step
# Epoch 155/500
# 26/26 - 0s - loss: 3.6842 - mean_absolute_error: 1.3662 - val_loss: 14.8980 - val_mean_absolute_error: 2.5179 - 80ms/epoch - 3ms/step
# Epoch 156/500
# 26/26 - 0s - loss: 3.6553 - mean_absolute_error: 1.3445 - val_loss: 14.1954 - val_mean_absolute_error: 2.3978 - 86ms/epoch - 3ms/step
# Epoch 157/500
# 26/26 - 0s - loss: 3.8650 - mean_absolute_error: 1.3827 - val_loss: 13.8930 - val_mean_absolute_error: 2.4684 - 100ms/epoch - 4ms/step
# Epoch 158/500
# 26/26 - 0s - loss: 3.7332 - mean_absolute_error: 1.3732 - val_loss: 13.9748 - val_mean_absolute_error: 2.4891 - 87ms/epoch - 3ms/step
# Epoch 159/500
# 26/26 - 0s - loss: 4.0179 - mean_absolute_error: 1.4613 - val_loss: 13.8419 - val_mean_absolute_error: 2.4544 - 99ms/epoch - 4ms/step
# Epoch 160/500
# 26/26 - 0s - loss: 3.9558 - mean_absolute_error: 1.4360 - val_loss: 13.7073 - val_mean_absolute_error: 2.4280 - 97ms/epoch - 4ms/step
# Epoch 161/500
# 26/26 - 0s - loss: 3.7845 - mean_absolute_error: 1.3741 - val_loss: 13.7802 - val_mean_absolute_error: 2.4459 - 99ms/epoch - 4ms/step
# Epoch 162/500
# 26/26 - 0s - loss: 3.6554 - mean_absolute_error: 1.3739 - val_loss: 14.1066 - val_mean_absolute_error: 2.4515 - 87ms/epoch - 3ms/step
# Epoch 163/500
# 26/26 - 0s - loss: 3.5917 - mean_absolute_error: 1.3387 - val_loss: 14.6626 - val_mean_absolute_error: 2.4964 - 86ms/epoch - 3ms/step
# Epoch 164/500
# 26/26 - 0s - loss: 3.5371 - mean_absolute_error: 1.3448 - val_loss: 14.9876 - val_mean_absolute_error: 2.5485 - 84ms/epoch - 3ms/step
# Epoch 165/500
# 26/26 - 0s - loss: 3.6489 - mean_absolute_error: 1.3433 - val_loss: 14.9654 - val_mean_absolute_error: 2.5545 - 91ms/epoch - 4ms/step
# Epoch 166/500
# 26/26 - 0s - loss: 3.5066 - mean_absolute_error: 1.3422 - val_loss: 13.4878 - val_mean_absolute_error: 2.4523 - 88ms/epoch - 3ms/step
# Epoch 167/500
# 26/26 - 0s - loss: 3.5204 - mean_absolute_error: 1.3247 - val_loss: 13.9538 - val_mean_absolute_error: 2.4336 - 96ms/epoch - 4ms/step
# Epoch 168/500
# 26/26 - 0s - loss: 3.4885 - mean_absolute_error: 1.3326 - val_loss: 13.9918 - val_mean_absolute_error: 2.4287 - 79ms/epoch - 3ms/step
# Epoch 169/500
# 26/26 - 0s - loss: 3.4553 - mean_absolute_error: 1.3105 - val_loss: 13.8065 - val_mean_absolute_error: 2.4432 - 85ms/epoch - 3ms/step
# Epoch 170/500
# 26/26 - 0s - loss: 3.3987 - mean_absolute_error: 1.3196 - val_loss: 13.4684 - val_mean_absolute_error: 2.4062 - 89ms/epoch - 3ms/step
# Epoch 171/500
# 26/26 - 0s - loss: 3.5495 - mean_absolute_error: 1.3328 - val_loss: 13.4371 - val_mean_absolute_error: 2.4520 - 79ms/epoch - 3ms/step
# Epoch 172/500
# 26/26 - 0s - loss: 3.5919 - mean_absolute_error: 1.3197 - val_loss: 13.1844 - val_mean_absolute_error: 2.4089 - 97ms/epoch - 4ms/step
# Epoch 173/500
# 26/26 - 0s - loss: 3.4514 - mean_absolute_error: 1.3210 - val_loss: 13.3504 - val_mean_absolute_error: 2.4063 - 91ms/epoch - 4ms/step
# Epoch 174/500
# 26/26 - 0s - loss: 3.4636 - mean_absolute_error: 1.3392 - val_loss: 13.5204 - val_mean_absolute_error: 2.3738 - 81ms/epoch - 3ms/step
# Epoch 175/500
# 26/26 - 0s - loss: 3.4300 - mean_absolute_error: 1.3207 - val_loss: 14.2677 - val_mean_absolute_error: 2.4956 - 89ms/epoch - 3ms/step
# Epoch 176/500
# 26/26 - 0s - loss: 3.8651 - mean_absolute_error: 1.4381 - val_loss: 14.4728 - val_mean_absolute_error: 2.4505 - 83ms/epoch - 3ms/step
# Epoch 177/500
# 26/26 - 0s - loss: 3.4176 - mean_absolute_error: 1.3280 - val_loss: 13.8602 - val_mean_absolute_error: 2.4830 - 103ms/epoch - 4ms/step
# Epoch 178/500
# 26/26 - 0s - loss: 3.3764 - mean_absolute_error: 1.2979 - val_loss: 13.2732 - val_mean_absolute_error: 2.3994 - 87ms/epoch - 3ms/step
# Epoch 179/500
# 26/26 - 0s - loss: 3.3366 - mean_absolute_error: 1.2799 - val_loss: 14.3729 - val_mean_absolute_error: 2.5024 - 88ms/epoch - 3ms/step
# Epoch 180/500
# 26/26 - 0s - loss: 3.4350 - mean_absolute_error: 1.3450 - val_loss: 14.1785 - val_mean_absolute_error: 2.4760 - 95ms/epoch - 4ms/step
# Epoch 181/500
# 26/26 - 0s - loss: 3.2953 - mean_absolute_error: 1.2923 - val_loss: 14.3067 - val_mean_absolute_error: 2.4775 - 86ms/epoch - 3ms/step
# Epoch 182/500
# 26/26 - 0s - loss: 3.4037 - mean_absolute_error: 1.3223 - val_loss: 13.4249 - val_mean_absolute_error: 2.4479 - 87ms/epoch - 3ms/step
# Epoch 183/500
# 26/26 - 0s - loss: 3.1948 - mean_absolute_error: 1.2786 - val_loss: 14.2287 - val_mean_absolute_error: 2.4927 - 93ms/epoch - 4ms/step
# Epoch 184/500
# 26/26 - 0s - loss: 3.2244 - mean_absolute_error: 1.2753 - val_loss: 13.5319 - val_mean_absolute_error: 2.4121 - 83ms/epoch - 3ms/step
# Epoch 185/500
# 26/26 - 0s - loss: 3.1778 - mean_absolute_error: 1.2675 - val_loss: 13.4337 - val_mean_absolute_error: 2.4318 - 89ms/epoch - 3ms/step
# Epoch 186/500
# 26/26 - 0s - loss: 3.2520 - mean_absolute_error: 1.2934 - val_loss: 14.2806 - val_mean_absolute_error: 2.5529 - 78ms/epoch - 3ms/step
# Epoch 187/500
# 26/26 - 0s - loss: 3.2406 - mean_absolute_error: 1.2846 - val_loss: 13.5478 - val_mean_absolute_error: 2.4533 - 81ms/epoch - 3ms/step
# Epoch 188/500
# 26/26 - 0s - loss: 3.0193 - mean_absolute_error: 1.2253 - val_loss: 13.6507 - val_mean_absolute_error: 2.4146 - 88ms/epoch - 3ms/step
# Epoch 189/500
# 26/26 - 0s - loss: 3.0478 - mean_absolute_error: 1.2245 - val_loss: 14.0081 - val_mean_absolute_error: 2.4868 - 77ms/epoch - 3ms/step
# Epoch 190/500
# 26/26 - 0s - loss: 3.2007 - mean_absolute_error: 1.2965 - val_loss: 14.2246 - val_mean_absolute_error: 2.4829 - 101ms/epoch - 4ms/step
# Epoch 191/500
# 26/26 - 0s - loss: 3.1075 - mean_absolute_error: 1.2751 - val_loss: 14.4279 - val_mean_absolute_error: 2.5942 - 75ms/epoch - 3ms/step
# Epoch 192/500
# 26/26 - 0s - loss: 3.2825 - mean_absolute_error: 1.2998 - val_loss: 13.6985 - val_mean_absolute_error: 2.4179 - 98ms/epoch - 4ms/step
# Epoch 193/500
# 26/26 - 0s - loss: 3.0926 - mean_absolute_error: 1.2394 - val_loss: 14.3252 - val_mean_absolute_error: 2.5460 - 81ms/epoch - 3ms/step
# Epoch 194/500
# 26/26 - 0s - loss: 3.1913 - mean_absolute_error: 1.3026 - val_loss: 13.7260 - val_mean_absolute_error: 2.4396 - 91ms/epoch - 3ms/step
# Epoch 195/500
# 26/26 - 0s - loss: 2.9498 - mean_absolute_error: 1.1989 - val_loss: 13.6795 - val_mean_absolute_error: 2.4556 - 84ms/epoch - 3ms/step
# Epoch 196/500
# 26/26 - 0s - loss: 2.9121 - mean_absolute_error: 1.2085 - val_loss: 13.7188 - val_mean_absolute_error: 2.4047 - 88ms/epoch - 3ms/step
# Epoch 197/500
# 26/26 - 0s - loss: 2.9934 - mean_absolute_error: 1.2418 - val_loss: 13.5204 - val_mean_absolute_error: 2.4398 - 94ms/epoch - 4ms/step
# Epoch 198/500
# 26/26 - 0s - loss: 2.9283 - mean_absolute_error: 1.2179 - val_loss: 13.7901 - val_mean_absolute_error: 2.4742 - 85ms/epoch - 3ms/step
# Epoch 199/500
# 26/26 - 0s - loss: 2.8553 - mean_absolute_error: 1.2095 - val_loss: 13.6459 - val_mean_absolute_error: 2.5143 - 80ms/epoch - 3ms/step
# Epoch 200/500
# 26/26 - 0s - loss: 2.9073 - mean_absolute_error: 1.2329 - val_loss: 14.2069 - val_mean_absolute_error: 2.4842 - 98ms/epoch - 4ms/step
# Epoch 201/500
# 26/26 - 0s - loss: 2.9282 - mean_absolute_error: 1.2223 - val_loss: 13.9241 - val_mean_absolute_error: 2.5024 - 92ms/epoch - 4ms/step
# Epoch 202/500
# 26/26 - 0s - loss: 2.9761 - mean_absolute_error: 1.2279 - val_loss: 14.1134 - val_mean_absolute_error: 2.5395 - 80ms/epoch - 3ms/step
# Epoch 203/500
# 26/26 - 0s - loss: 3.0261 - mean_absolute_error: 1.2640 - val_loss: 13.1214 - val_mean_absolute_error: 2.3794 - 86ms/epoch - 3ms/step
# Epoch 204/500
# 26/26 - 0s - loss: 3.0006 - mean_absolute_error: 1.2549 - val_loss: 13.7233 - val_mean_absolute_error: 2.5435 - 96ms/epoch - 4ms/step
# Epoch 205/500
# 26/26 - 0s - loss: 3.1042 - mean_absolute_error: 1.2709 - val_loss: 13.5345 - val_mean_absolute_error: 2.4178 - 79ms/epoch - 3ms/step
# Epoch 206/500
# 26/26 - 0s - loss: 2.8132 - mean_absolute_error: 1.1909 - val_loss: 13.6080 - val_mean_absolute_error: 2.4099 - 89ms/epoch - 3ms/step
# Epoch 207/500
# 26/26 - 0s - loss: 2.9070 - mean_absolute_error: 1.2222 - val_loss: 13.3862 - val_mean_absolute_error: 2.4668 - 86ms/epoch - 3ms/step
# Epoch 208/500
# 26/26 - 0s - loss: 2.8928 - mean_absolute_error: 1.2339 - val_loss: 13.7909 - val_mean_absolute_error: 2.4771 - 99ms/epoch - 4ms/step
# Epoch 209/500
# 26/26 - 0s - loss: 2.8830 - mean_absolute_error: 1.2148 - val_loss: 13.9153 - val_mean_absolute_error: 2.4578 - 85ms/epoch - 3ms/step
# Epoch 210/500
# 26/26 - 0s - loss: 2.8538 - mean_absolute_error: 1.2075 - val_loss: 14.8561 - val_mean_absolute_error: 2.5998 - 86ms/epoch - 3ms/step
# Epoch 211/500
# 26/26 - 0s - loss: 3.2409 - mean_absolute_error: 1.3198 - val_loss: 13.1412 - val_mean_absolute_error: 2.4756 - 91ms/epoch - 4ms/step
# Epoch 212/500
# 26/26 - 0s - loss: 2.8411 - mean_absolute_error: 1.1833 - val_loss: 13.2235 - val_mean_absolute_error: 2.3784 - 111ms/epoch - 4ms/step
# Epoch 213/500
# 26/26 - 0s - loss: 2.7008 - mean_absolute_error: 1.1756 - val_loss: 13.0062 - val_mean_absolute_error: 2.3920 - 96ms/epoch - 4ms/step
# Epoch 214/500
# 26/26 - 0s - loss: 2.8136 - mean_absolute_error: 1.1925 - val_loss: 12.7393 - val_mean_absolute_error: 2.4049 - 90ms/epoch - 3ms/step
# Epoch 215/500
# 26/26 - 0s - loss: 2.6569 - mean_absolute_error: 1.1625 - val_loss: 12.7794 - val_mean_absolute_error: 2.3773 - 91ms/epoch - 3ms/step
# Epoch 216/500
# 26/26 - 0s - loss: 2.6010 - mean_absolute_error: 1.1286 - val_loss: 13.9322 - val_mean_absolute_error: 2.4725 - 92ms/epoch - 4ms/step
# Epoch 217/500
# 26/26 - 0s - loss: 2.6741 - mean_absolute_error: 1.1771 - val_loss: 13.4784 - val_mean_absolute_error: 2.4345 - 87ms/epoch - 3ms/step
# Epoch 218/500
# 26/26 - 0s - loss: 3.3826 - mean_absolute_error: 1.3814 - val_loss: 13.9806 - val_mean_absolute_error: 2.4739 - 82ms/epoch - 3ms/step
# Epoch 219/500
# 26/26 - 0s - loss: 2.7835 - mean_absolute_error: 1.1985 - val_loss: 13.9882 - val_mean_absolute_error: 2.5469 - 90ms/epoch - 3ms/step
# Epoch 220/500
# 26/26 - 0s - loss: 2.8045 - mean_absolute_error: 1.1933 - val_loss: 13.6948 - val_mean_absolute_error: 2.4466 - 79ms/epoch - 3ms/step
# Epoch 221/500
# 26/26 - 0s - loss: 2.7069 - mean_absolute_error: 1.1897 - val_loss: 13.0332 - val_mean_absolute_error: 2.3601 - 84ms/epoch - 3ms/step
# Epoch 222/500
# 26/26 - 0s - loss: 2.7212 - mean_absolute_error: 1.1826 - val_loss: 12.9287 - val_mean_absolute_error: 2.3785 - 93ms/epoch - 4ms/step
# Epoch 223/500
# 26/26 - 0s - loss: 2.8111 - mean_absolute_error: 1.2237 - val_loss: 12.9810 - val_mean_absolute_error: 2.3629 - 94ms/epoch - 4ms/step
# Epoch 224/500
# 26/26 - 0s - loss: 2.6703 - mean_absolute_error: 1.1976 - val_loss: 13.1198 - val_mean_absolute_error: 2.4557 - 92ms/epoch - 4ms/step
# Epoch 225/500
# 26/26 - 0s - loss: 2.5496 - mean_absolute_error: 1.1331 - val_loss: 12.9036 - val_mean_absolute_error: 2.3644 - 91ms/epoch - 4ms/step
# Epoch 226/500
# 26/26 - 0s - loss: 2.5138 - mean_absolute_error: 1.1520 - val_loss: 13.0017 - val_mean_absolute_error: 2.3818 - 79ms/epoch - 3ms/step
# Epoch 227/500
# 26/26 - 0s - loss: 2.6335 - mean_absolute_error: 1.1507 - val_loss: 12.6732 - val_mean_absolute_error: 2.3604 - 88ms/epoch - 3ms/step
# Epoch 228/500
# 26/26 - 0s - loss: 2.5411 - mean_absolute_error: 1.1480 - val_loss: 13.2055 - val_mean_absolute_error: 2.4030 - 94ms/epoch - 4ms/step
# Epoch 229/500
# 26/26 - 0s - loss: 2.5498 - mean_absolute_error: 1.1423 - val_loss: 13.2059 - val_mean_absolute_error: 2.4561 - 85ms/epoch - 3ms/step
# Epoch 230/500
# 26/26 - 0s - loss: 2.8357 - mean_absolute_error: 1.2612 - val_loss: 14.3251 - val_mean_absolute_error: 2.6453 - 76ms/epoch - 3ms/step
# Epoch 231/500
# 26/26 - 0s - loss: 2.6296 - mean_absolute_error: 1.1509 - val_loss: 13.1560 - val_mean_absolute_error: 2.4133 - 83ms/epoch - 3ms/step
# Epoch 232/500
# 26/26 - 0s - loss: 2.5644 - mean_absolute_error: 1.1652 - val_loss: 13.3038 - val_mean_absolute_error: 2.3855 - 104ms/epoch - 4ms/step
# Epoch 233/500
# 26/26 - 0s - loss: 2.7576 - mean_absolute_error: 1.1851 - val_loss: 13.2977 - val_mean_absolute_error: 2.4365 - 103ms/epoch - 4ms/step
# Epoch 234/500
# 26/26 - 0s - loss: 2.5204 - mean_absolute_error: 1.1598 - val_loss: 12.7125 - val_mean_absolute_error: 2.3847 - 77ms/epoch - 3ms/step
# Epoch 235/500
# 26/26 - 0s - loss: 2.4360 - mean_absolute_error: 1.1228 - val_loss: 12.8318 - val_mean_absolute_error: 2.3464 - 76ms/epoch - 3ms/step
# Epoch 236/500
# 26/26 - 0s - loss: 2.5367 - mean_absolute_error: 1.1547 - val_loss: 13.6876 - val_mean_absolute_error: 2.4568 - 88ms/epoch - 3ms/step
# Epoch 237/500
# 26/26 - 0s - loss: 2.4791 - mean_absolute_error: 1.1557 - val_loss: 13.3453 - val_mean_absolute_error: 2.4657 - 75ms/epoch - 3ms/step
# Epoch 238/500
# 26/26 - 0s - loss: 2.3216 - mean_absolute_error: 1.0896 - val_loss: 13.3991 - val_mean_absolute_error: 2.3963 - 79ms/epoch - 3ms/step
# Epoch 239/500
# 26/26 - 0s - loss: 2.2782 - mean_absolute_error: 1.0888 - val_loss: 12.9181 - val_mean_absolute_error: 2.3811 - 82ms/epoch - 3ms/step
# Epoch 240/500
# 26/26 - 0s - loss: 2.4255 - mean_absolute_error: 1.1237 - val_loss: 13.9277 - val_mean_absolute_error: 2.5004 - 83ms/epoch - 3ms/step
# Epoch 241/500
# 26/26 - 0s - loss: 2.3118 - mean_absolute_error: 1.0852 - val_loss: 13.1687 - val_mean_absolute_error: 2.3529 - 81ms/epoch - 3ms/step
# Epoch 242/500
# 26/26 - 0s - loss: 2.5357 - mean_absolute_error: 1.1629 - val_loss: 12.4882 - val_mean_absolute_error: 2.3653 - 77ms/epoch - 3ms/step
# Epoch 243/500
# 26/26 - 0s - loss: 2.4788 - mean_absolute_error: 1.1503 - val_loss: 14.0211 - val_mean_absolute_error: 2.4313 - 77ms/epoch - 3ms/step
# Epoch 244/500
# 26/26 - 0s - loss: 2.2292 - mean_absolute_error: 1.0647 - val_loss: 12.6301 - val_mean_absolute_error: 2.3334 - 84ms/epoch - 3ms/step
# Epoch 245/500
# 26/26 - 0s - loss: 2.2299 - mean_absolute_error: 1.0851 - val_loss: 13.4672 - val_mean_absolute_error: 2.4488 - 94ms/epoch - 4ms/step
# Epoch 246/500
# 26/26 - 0s - loss: 2.2724 - mean_absolute_error: 1.0757 - val_loss: 12.9160 - val_mean_absolute_error: 2.4231 - 73ms/epoch - 3ms/step
# Epoch 247/500
# 26/26 - 0s - loss: 2.4192 - mean_absolute_error: 1.1285 - val_loss: 12.7932 - val_mean_absolute_error: 2.3516 - 90ms/epoch - 3ms/step
# Epoch 248/500
# 26/26 - 0s - loss: 2.1771 - mean_absolute_error: 1.0619 - val_loss: 13.2427 - val_mean_absolute_error: 2.4369 - 80ms/epoch - 3ms/step
# Epoch 249/500
# 26/26 - 0s - loss: 2.2244 - mean_absolute_error: 1.0748 - val_loss: 13.5007 - val_mean_absolute_error: 2.4605 - 85ms/epoch - 3ms/step
# Epoch 250/500
# 26/26 - 0s - loss: 2.2750 - mean_absolute_error: 1.0947 - val_loss: 12.6697 - val_mean_absolute_error: 2.3710 - 92ms/epoch - 4ms/step
# Epoch 251/500
# 26/26 - 0s - loss: 2.3242 - mean_absolute_error: 1.0862 - val_loss: 12.8374 - val_mean_absolute_error: 2.3889 - 98ms/epoch - 4ms/step
# Epoch 252/500
# 26/26 - 0s - loss: 2.2776 - mean_absolute_error: 1.0971 - val_loss: 13.1592 - val_mean_absolute_error: 2.4290 - 92ms/epoch - 4ms/step
# Epoch 253/500
# 26/26 - 0s - loss: 2.1775 - mean_absolute_error: 1.0678 - val_loss: 13.1752 - val_mean_absolute_error: 2.4020 - 81ms/epoch - 3ms/step
# Epoch 254/500
# 26/26 - 0s - loss: 2.2749 - mean_absolute_error: 1.0859 - val_loss: 13.7888 - val_mean_absolute_error: 2.4478 - 81ms/epoch - 3ms/step
# Epoch 255/500
# 26/26 - 0s - loss: 2.1285 - mean_absolute_error: 1.0398 - val_loss: 12.9344 - val_mean_absolute_error: 2.3865 - 101ms/epoch - 4ms/step
# Epoch 256/500
# 26/26 - 0s - loss: 2.3658 - mean_absolute_error: 1.1279 - val_loss: 13.5294 - val_mean_absolute_error: 2.4537 - 86ms/epoch - 3ms/step
# Epoch 257/500
# 26/26 - 0s - loss: 2.3126 - mean_absolute_error: 1.1106 - val_loss: 13.2547 - val_mean_absolute_error: 2.4298 - 88ms/epoch - 3ms/step
# Epoch 258/500
# 26/26 - 0s - loss: 2.1846 - mean_absolute_error: 1.0625 - val_loss: 12.9660 - val_mean_absolute_error: 2.3859 - 78ms/epoch - 3ms/step
# Epoch 259/500
# 26/26 - 0s - loss: 2.2030 - mean_absolute_error: 1.0711 - val_loss: 13.1719 - val_mean_absolute_error: 2.3676 - 82ms/epoch - 3ms/step
# Epoch 260/500
# 26/26 - 0s - loss: 2.1698 - mean_absolute_error: 1.0453 - val_loss: 13.3536 - val_mean_absolute_error: 2.4550 - 90ms/epoch - 3ms/step
# Epoch 261/500
# 26/26 - 0s - loss: 2.1994 - mean_absolute_error: 1.0858 - val_loss: 13.5948 - val_mean_absolute_error: 2.5114 - 75ms/epoch - 3ms/step
# Epoch 262/500
# 26/26 - 0s - loss: 2.1315 - mean_absolute_error: 1.0612 - val_loss: 13.2173 - val_mean_absolute_error: 2.3944 - 76ms/epoch - 3ms/step
# Epoch 263/500
# 26/26 - 0s - loss: 2.2341 - mean_absolute_error: 1.0779 - val_loss: 13.1761 - val_mean_absolute_error: 2.4547 - 74ms/epoch - 3ms/step
# Epoch 264/500
# 26/26 - 0s - loss: 2.1962 - mean_absolute_error: 1.0821 - val_loss: 13.1810 - val_mean_absolute_error: 2.3662 - 74ms/epoch - 3ms/step
# Epoch 265/500
# 26/26 - 0s - loss: 2.0477 - mean_absolute_error: 1.0344 - val_loss: 13.8241 - val_mean_absolute_error: 2.4669 - 83ms/epoch - 3ms/step
# Epoch 266/500
# 26/26 - 0s - loss: 2.2946 - mean_absolute_error: 1.1114 - val_loss: 12.5297 - val_mean_absolute_error: 2.3948 - 74ms/epoch - 3ms/step
# Epoch 267/500
# 26/26 - 0s - loss: 2.1489 - mean_absolute_error: 1.0463 - val_loss: 13.5199 - val_mean_absolute_error: 2.4026 - 81ms/epoch - 3ms/step
# Epoch 268/500
# 26/26 - 0s - loss: 2.0996 - mean_absolute_error: 1.0343 - val_loss: 13.2695 - val_mean_absolute_error: 2.3866 - 99ms/epoch - 4ms/step
# Epoch 269/500
# 26/26 - 0s - loss: 1.9951 - mean_absolute_error: 1.0091 - val_loss: 12.7749 - val_mean_absolute_error: 2.3596 - 87ms/epoch - 3ms/step
# Epoch 270/500
# 26/26 - 0s - loss: 1.9126 - mean_absolute_error: 0.9910 - val_loss: 13.1331 - val_mean_absolute_error: 2.3810 - 78ms/epoch - 3ms/step
# Epoch 271/500
# 26/26 - 0s - loss: 1.9740 - mean_absolute_error: 1.0286 - val_loss: 13.6670 - val_mean_absolute_error: 2.4216 - 83ms/epoch - 3ms/step
# Epoch 272/500
# 26/26 - 0s - loss: 2.0052 - mean_absolute_error: 1.0160 - val_loss: 12.9178 - val_mean_absolute_error: 2.3879 - 91ms/epoch - 4ms/step
# Epoch 273/500
# 26/26 - 0s - loss: 2.2661 - mean_absolute_error: 1.1146 - val_loss: 12.9129 - val_mean_absolute_error: 2.3992 - 80ms/epoch - 3ms/step
# Epoch 274/500
# 26/26 - 0s - loss: 2.0800 - mean_absolute_error: 1.0408 - val_loss: 13.4808 - val_mean_absolute_error: 2.4380 - 93ms/epoch - 4ms/step
# Epoch 275/500
# 26/26 - 0s - loss: 2.0177 - mean_absolute_error: 1.0293 - val_loss: 12.6192 - val_mean_absolute_error: 2.3515 - 77ms/epoch - 3ms/step
# Epoch 276/500
# 26/26 - 0s - loss: 1.9976 - mean_absolute_error: 1.0213 - val_loss: 13.0025 - val_mean_absolute_error: 2.3638 - 88ms/epoch - 3ms/step
# Epoch 277/500
# 26/26 - 0s - loss: 1.9685 - mean_absolute_error: 1.0180 - val_loss: 12.5916 - val_mean_absolute_error: 2.3564 - 97ms/epoch - 4ms/step
# Epoch 278/500
# 26/26 - 0s - loss: 2.0486 - mean_absolute_error: 1.0221 - val_loss: 12.8713 - val_mean_absolute_error: 2.3404 - 80ms/epoch - 3ms/step
# Epoch 279/500
# 26/26 - 0s - loss: 2.0399 - mean_absolute_error: 1.0308 - val_loss: 13.2976 - val_mean_absolute_error: 2.4773 - 88ms/epoch - 3ms/step
# Epoch 280/500
# 26/26 - 0s - loss: 2.2382 - mean_absolute_error: 1.0996 - val_loss: 13.3667 - val_mean_absolute_error: 2.3979 - 79ms/epoch - 3ms/step
# Epoch 281/500
# 26/26 - 0s - loss: 2.0279 - mean_absolute_error: 1.0302 - val_loss: 13.0688 - val_mean_absolute_error: 2.3484 - 77ms/epoch - 3ms/step
# Epoch 282/500
# 26/26 - 0s - loss: 1.9281 - mean_absolute_error: 0.9972 - val_loss: 12.9570 - val_mean_absolute_error: 2.3628 - 80ms/epoch - 3ms/step
# Epoch 283/500
# 26/26 - 0s - loss: 1.9182 - mean_absolute_error: 0.9896 - val_loss: 13.2144 - val_mean_absolute_error: 2.4219 - 92ms/epoch - 4ms/step
# Epoch 284/500
# 26/26 - 0s - loss: 1.8775 - mean_absolute_error: 0.9495 - val_loss: 13.5028 - val_mean_absolute_error: 2.4073 - 90ms/epoch - 3ms/step
# Epoch 285/500
# 26/26 - 0s - loss: 1.9687 - mean_absolute_error: 1.0170 - val_loss: 13.0488 - val_mean_absolute_error: 2.3530 - 88ms/epoch - 3ms/step
# Epoch 286/500
# 26/26 - 0s - loss: 1.9667 - mean_absolute_error: 1.0477 - val_loss: 13.1108 - val_mean_absolute_error: 2.3902 - 89ms/epoch - 3ms/step
# Epoch 287/500
# 26/26 - 0s - loss: 1.9872 - mean_absolute_error: 1.0140 - val_loss: 13.0124 - val_mean_absolute_error: 2.4261 - 90ms/epoch - 3ms/step
# Epoch 288/500
# 26/26 - 0s - loss: 1.9788 - mean_absolute_error: 0.9965 - val_loss: 13.7471 - val_mean_absolute_error: 2.4782 - 94ms/epoch - 4ms/step
# Epoch 289/500
# 26/26 - 0s - loss: 1.9846 - mean_absolute_error: 1.0153 - val_loss: 12.9764 - val_mean_absolute_error: 2.3960 - 94ms/epoch - 4ms/step
# Epoch 290/500
# 26/26 - 0s - loss: 1.7964 - mean_absolute_error: 0.9555 - val_loss: 12.6799 - val_mean_absolute_error: 2.3656 - 103ms/epoch - 4ms/step
# Epoch 291/500
# 26/26 - 0s - loss: 1.8226 - mean_absolute_error: 0.9791 - val_loss: 13.3784 - val_mean_absolute_error: 2.3882 - 100ms/epoch - 4ms/step
# Epoch 292/500
# 26/26 - 0s - loss: 1.8797 - mean_absolute_error: 0.9743 - val_loss: 13.1402 - val_mean_absolute_error: 2.4022 - 83ms/epoch - 3ms/step
# Epoch 293/500
# 26/26 - 0s - loss: 1.8274 - mean_absolute_error: 1.0031 - val_loss: 12.9215 - val_mean_absolute_error: 2.3645 - 91ms/epoch - 3ms/step
# Epoch 294/500
# 26/26 - 0s - loss: 1.7971 - mean_absolute_error: 0.9736 - val_loss: 13.5197 - val_mean_absolute_error: 2.4182 - 89ms/epoch - 3ms/step
# Epoch 295/500
# 26/26 - 0s - loss: 1.9246 - mean_absolute_error: 0.9993 - val_loss: 13.0939 - val_mean_absolute_error: 2.3997 - 83ms/epoch - 3ms/step
# Epoch 296/500
# 26/26 - 0s - loss: 1.7666 - mean_absolute_error: 0.9412 - val_loss: 13.3620 - val_mean_absolute_error: 2.4194 - 77ms/epoch - 3ms/step
# Epoch 297/500
# 26/26 - 0s - loss: 1.9098 - mean_absolute_error: 1.0056 - val_loss: 13.7816 - val_mean_absolute_error: 2.4316 - 84ms/epoch - 3ms/step
# Epoch 298/500
# 26/26 - 0s - loss: 1.8175 - mean_absolute_error: 0.9558 - val_loss: 12.5835 - val_mean_absolute_error: 2.3255 - 78ms/epoch - 3ms/step
# Epoch 299/500
# 26/26 - 0s - loss: 1.7260 - mean_absolute_error: 0.9331 - val_loss: 13.5691 - val_mean_absolute_error: 2.3986 - 89ms/epoch - 3ms/step
# Epoch 300/500
# 26/26 - 0s - loss: 1.8741 - mean_absolute_error: 0.9881 - val_loss: 13.0078 - val_mean_absolute_error: 2.3824 - 90ms/epoch - 3ms/step
# Epoch 301/500
# 26/26 - 0s - loss: 1.8574 - mean_absolute_error: 0.9752 - val_loss: 12.8824 - val_mean_absolute_error: 2.3512 - 93ms/epoch - 4ms/step
# Epoch 302/500
# 26/26 - 0s - loss: 1.7596 - mean_absolute_error: 0.9350 - val_loss: 13.7866 - val_mean_absolute_error: 2.4342 - 78ms/epoch - 3ms/step
# Epoch 303/500
# 26/26 - 0s - loss: 1.6987 - mean_absolute_error: 0.9072 - val_loss: 12.9053 - val_mean_absolute_error: 2.3519 - 80ms/epoch - 3ms/step
# Epoch 304/500
# 26/26 - 0s - loss: 1.9057 - mean_absolute_error: 1.0149 - val_loss: 13.5093 - val_mean_absolute_error: 2.4688 - 85ms/epoch - 3ms/step
# Epoch 305/500
# 26/26 - 0s - loss: 1.9755 - mean_absolute_error: 1.0148 - val_loss: 13.7140 - val_mean_absolute_error: 2.4526 - 110ms/epoch - 4ms/step
# Epoch 306/500
# 26/26 - 0s - loss: 1.8296 - mean_absolute_error: 0.9647 - val_loss: 14.0771 - val_mean_absolute_error: 2.5267 - 86ms/epoch - 3ms/step
# Epoch 307/500
# 26/26 - 0s - loss: 2.1643 - mean_absolute_error: 1.0940 - val_loss: 13.1221 - val_mean_absolute_error: 2.3829 - 101ms/epoch - 4ms/step
# Epoch 308/500
# 26/26 - 0s - loss: 1.9375 - mean_absolute_error: 1.0273 - val_loss: 13.3315 - val_mean_absolute_error: 2.4116 - 85ms/epoch - 3ms/step
# Epoch 309/500
# 26/26 - 0s - loss: 1.6754 - mean_absolute_error: 0.9255 - val_loss: 12.8975 - val_mean_absolute_error: 2.3284 - 108ms/epoch - 4ms/step
# Epoch 310/500
# 26/26 - 0s - loss: 1.7340 - mean_absolute_error: 0.9389 - val_loss: 13.0774 - val_mean_absolute_error: 2.3618 - 82ms/epoch - 3ms/step
# Epoch 311/500
# 26/26 - 0s - loss: 1.7032 - mean_absolute_error: 0.9450 - val_loss: 12.9100 - val_mean_absolute_error: 2.3468 - 96ms/epoch - 4ms/step
# Epoch 312/500
# 26/26 - 0s - loss: 1.6068 - mean_absolute_error: 0.8997 - val_loss: 13.2280 - val_mean_absolute_error: 2.3238 - 86ms/epoch - 3ms/step
# Epoch 313/500
# 26/26 - 0s - loss: 1.7353 - mean_absolute_error: 0.9446 - val_loss: 12.7430 - val_mean_absolute_error: 2.3298 - 92ms/epoch - 4ms/step
# Epoch 314/500
# 26/26 - 0s - loss: 1.7572 - mean_absolute_error: 0.9615 - val_loss: 13.3075 - val_mean_absolute_error: 2.3976 - 87ms/epoch - 3ms/step
# Epoch 315/500
# 26/26 - 0s - loss: 1.6946 - mean_absolute_error: 0.9072 - val_loss: 12.9102 - val_mean_absolute_error: 2.3430 - 76ms/epoch - 3ms/step
# Epoch 316/500
# 26/26 - 0s - loss: 1.6336 - mean_absolute_error: 0.9213 - val_loss: 13.4516 - val_mean_absolute_error: 2.3492 - 81ms/epoch - 3ms/step
# Epoch 317/500
# 26/26 - 0s - loss: 1.7183 - mean_absolute_error: 0.9565 - val_loss: 13.3175 - val_mean_absolute_error: 2.3902 - 88ms/epoch - 3ms/step
# Epoch 318/500
# 26/26 - 0s - loss: 1.8396 - mean_absolute_error: 0.9877 - val_loss: 13.5899 - val_mean_absolute_error: 2.3633 - 76ms/epoch - 3ms/step
# Epoch 319/500
# 26/26 - 0s - loss: 1.8119 - mean_absolute_error: 0.9974 - val_loss: 13.1090 - val_mean_absolute_error: 2.3899 - 99ms/epoch - 4ms/step
# ...
# Epoch 393/500
# 26/26 - 0s - loss: 1.7098 - mean_absolute_error: 0.9747 - val_loss: 13.5938 - val_mean_absolute_error: 2.3797 - 81ms/epoch - 3ms/step
# Epoch 394/500
# 26/26 - 0s - loss: 1.4365 - mean_absolute_error: 0.8865 - val_loss: 13.7899 - val_mean_absolute_error: 2.4397 - 94ms/epoch - 4ms/step
# Epoch 395/500
# 26/26 - 0s - loss: 1.4007 - mean_absolute_error: 0.8749 - val_loss: 13.8314 - val_mean_absolute_error: 2.4149 - 82ms/epoch - 3ms/step
# Epoch 396/500
# 26/26 - 0s - loss: 1.2425 - mean_absolute_error: 0.8061 - val_loss: 12.7517 - val_mean_absolute_error: 2.3239 - 94ms/epoch - 4ms/step
# Epoch 397/500
# 26/26 - 0s - loss: 1.3231 - mean_absolute_error: 0.8161 - val_loss: 13.6169 - val_mean_absolute_error: 2.3542 - 89ms/epoch - 3ms/step
# Epoch 398/500
# 26/26 - 0s - loss: 1.2486 - mean_absolute_error: 0.8073 - val_loss: 12.9624 - val_mean_absolute_error: 2.3469 - 86ms/epoch - 3ms/step
# Epoch 399/500
# 26/26 - 0s - loss: 1.2443 - mean_absolute_error: 0.7910 - val_loss: 12.7482 - val_mean_absolute_error: 2.3191 - 110ms/epoch - 4ms/step
# Epoch 400/500
# 26/26 - 0s - loss: 1.1532 - mean_absolute_error: 0.7664 - val_loss: 13.5373 - val_mean_absolute_error: 2.3407 - 79ms/epoch - 3ms/step
# Epoch 401/500
# 26/26 - 0s - loss: 1.2708 - mean_absolute_error: 0.8136 - val_loss: 13.9421 - val_mean_absolute_error: 2.4348 - 90ms/epoch - 3ms/step
# Epoch 402/500
# 26/26 - 0s - loss: 1.1822 - mean_absolute_error: 0.8065 - val_loss: 13.0355 - val_mean_absolute_error: 2.3232 - 89ms/epoch - 3ms/step
# Epoch 403/500
# 26/26 - 0s - loss: 1.1538 - mean_absolute_error: 0.7721 - val_loss: 13.0159 - val_mean_absolute_error: 2.3344 - 95ms/epoch - 4ms/step
# Epoch 404/500
# 26/26 - 0s - loss: 1.3367 - mean_absolute_error: 0.8297 - val_loss: 13.0750 - val_mean_absolute_error: 2.3629 - 80ms/epoch - 3ms/step
# Epoch 405/500
# 26/26 - 0s - loss: 1.1912 - mean_absolute_error: 0.7986 - val_loss: 13.0495 - val_mean_absolute_error: 2.3167 - 84ms/epoch - 3ms/step
# Epoch 406/500
# 26/26 - 0s - loss: 1.1910 - mean_absolute_error: 0.8009 - val_loss: 13.2546 - val_mean_absolute_error: 2.3788 - 89ms/epoch - 3ms/step
# Epoch 407/500
# 26/26 - 0s - loss: 1.2229 - mean_absolute_error: 0.8245 - val_loss: 13.2485 - val_mean_absolute_error: 2.3594 - 96ms/epoch - 4ms/step
# Epoch 408/500
# 26/26 - 0s - loss: 1.1093 - mean_absolute_error: 0.7590 - val_loss: 12.9432 - val_mean_absolute_error: 2.3296 - 86ms/epoch - 3ms/step
# Epoch 409/500
# 26/26 - 0s - loss: 1.1511 - mean_absolute_error: 0.7898 - val_loss: 13.7228 - val_mean_absolute_error: 2.3868 - 92ms/epoch - 4ms/step
# Epoch 410/500
# 26/26 - 0s - loss: 1.1947 - mean_absolute_error: 0.7882 - val_loss: 12.9815 - val_mean_absolute_error: 2.3380 - 95ms/epoch - 4ms/step
# Epoch 411/500
# 26/26 - 0s - loss: 1.3305 - mean_absolute_error: 0.8554 - val_loss: 13.5677 - val_mean_absolute_error: 2.3259 - 84ms/epoch - 3ms/step
# Epoch 412/500
# 26/26 - 0s - loss: 1.1843 - mean_absolute_error: 0.7984 - val_loss: 13.2732 - val_mean_absolute_error: 2.3498 - 81ms/epoch - 3ms/step
# Epoch 413/500
# 26/26 - 0s - loss: 1.1760 - mean_absolute_error: 0.7841 - val_loss: 14.0528 - val_mean_absolute_error: 2.4334 - 85ms/epoch - 3ms/step
# Epoch 414/500
# 26/26 - 0s - loss: 1.4270 - mean_absolute_error: 0.8914 - val_loss: 13.2322 - val_mean_absolute_error: 2.3593 - 85ms/epoch - 3ms/step
# Epoch 415/500
# 26/26 - 0s - loss: 1.2844 - mean_absolute_error: 0.8251 - val_loss: 13.1815 - val_mean_absolute_error: 2.3439 - 109ms/epoch - 4ms/step
# Epoch 416/500
# 26/26 - 0s - loss: 1.5098 - mean_absolute_error: 0.9163 - val_loss: 12.8306 - val_mean_absolute_error: 2.2977 - 99ms/epoch - 4ms/step
# Epoch 417/500
# 26/26 - 0s - loss: 1.1243 - mean_absolute_error: 0.7757 - val_loss: 13.6505 - val_mean_absolute_error: 2.3752 - 91ms/epoch - 3ms/step
# Epoch 418/500
# 26/26 - 0s - loss: 1.0796 - mean_absolute_error: 0.7382 - val_loss: 12.9027 - val_mean_absolute_error: 2.2988 - 79ms/epoch - 3ms/step
# Epoch 419/500
# 26/26 - 0s - loss: 1.0796 - mean_absolute_error: 0.7325 - val_loss: 13.2776 - val_mean_absolute_error: 2.3768 - 92ms/epoch - 4ms/step
# Epoch 420/500
# 26/26 - 0s - loss: 1.1775 - mean_absolute_error: 0.7820 - val_loss: 13.4219 - val_mean_absolute_error: 2.4068 - 78ms/epoch - 3ms/step
# Epoch 421/500
# 26/26 - 0s - loss: 1.1163 - mean_absolute_error: 0.7662 - val_loss: 13.5766 - val_mean_absolute_error: 2.4543 - 99ms/epoch - 4ms/step
# Epoch 422/500
# 26/26 - 0s - loss: 1.1327 - mean_absolute_error: 0.7675 - val_loss: 13.2466 - val_mean_absolute_error: 2.3635 - 94ms/epoch - 4ms/step
# Epoch 423/500
# 26/26 - 0s - loss: 1.0509 - mean_absolute_error: 0.7267 - val_loss: 13.4205 - val_mean_absolute_error: 2.3673 - 82ms/epoch - 3ms/step
# Epoch 424/500
# 26/26 - 0s - loss: 1.0884 - mean_absolute_error: 0.7447 - val_loss: 13.7225 - val_mean_absolute_error: 2.3996 - 77ms/epoch - 3ms/step
# Epoch 425/500
# 26/26 - 0s - loss: 1.0939 - mean_absolute_error: 0.7560 - val_loss: 13.4499 - val_mean_absolute_error: 2.3672 - 83ms/epoch - 3ms/step
# Epoch 426/500
# 26/26 - 0s - loss: 1.1687 - mean_absolute_error: 0.7969 - val_loss: 13.1842 - val_mean_absolute_error: 2.3462 - 93ms/epoch - 4ms/step
# Epoch 427/500
# 26/26 - 0s - loss: 1.2099 - mean_absolute_error: 0.7921 - val_loss: 13.3827 - val_mean_absolute_error: 2.3941 - 78ms/epoch - 3ms/step
# Epoch 428/500
# 26/26 - 0s - loss: 1.1570 - mean_absolute_error: 0.7969 - val_loss: 13.5826 - val_mean_absolute_error: 2.3891 - 89ms/epoch - 3ms/step
# Epoch 429/500
# 26/26 - 0s - loss: 1.3483 - mean_absolute_error: 0.8732 - val_loss: 13.2039 - val_mean_absolute_error: 2.3075 - 88ms/epoch - 3ms/step
# Epoch 430/500
# 26/26 - 0s - loss: 1.1808 - mean_absolute_error: 0.7934 - val_loss: 14.1178 - val_mean_absolute_error: 2.3869 - 85ms/epoch - 3ms/step
# Epoch 431/500
# 26/26 - 0s - loss: 1.0443 - mean_absolute_error: 0.7393 - val_loss: 12.9331 - val_mean_absolute_error: 2.2938 - 90ms/epoch - 3ms/step
# Epoch 432/500
# 26/26 - 0s - loss: 1.0674 - mean_absolute_error: 0.7378 - val_loss: 13.0481 - val_mean_absolute_error: 2.3382 - 102ms/epoch - 4ms/step
# Epoch 433/500
# 26/26 - 0s - loss: 1.0107 - mean_absolute_error: 0.7136 - val_loss: 13.4002 - val_mean_absolute_error: 2.4080 - 78ms/epoch - 3ms/step
# Epoch 434/500
# 26/26 - 0s - loss: 1.1372 - mean_absolute_error: 0.7674 - val_loss: 13.3744 - val_mean_absolute_error: 2.3478 - 80ms/epoch - 3ms/step
# Epoch 435/500
# 26/26 - 0s - loss: 1.0992 - mean_absolute_error: 0.7509 - val_loss: 13.8982 - val_mean_absolute_error: 2.4018 - 98ms/epoch - 4ms/step
# Epoch 436/500
# 26/26 - 0s - loss: 1.1926 - mean_absolute_error: 0.7827 - val_loss: 13.2429 - val_mean_absolute_error: 2.3422 - 89ms/epoch - 3ms/step
# Epoch 437/500
# 26/26 - 0s - loss: 1.0575 - mean_absolute_error: 0.7413 - val_loss: 13.8039 - val_mean_absolute_error: 2.4271 - 77ms/epoch - 3ms/step
# Epoch 438/500
# 26/26 - 0s - loss: 1.0959 - mean_absolute_error: 0.7654 - val_loss: 13.5048 - val_mean_absolute_error: 2.4030 - 98ms/epoch - 4ms/step
# Epoch 439/500
# 26/26 - 0s - loss: 1.1001 - mean_absolute_error: 0.7508 - val_loss: 13.6134 - val_mean_absolute_error: 2.3818 - 82ms/epoch - 3ms/step
# Epoch 440/500
# 26/26 - 0s - loss: 1.1498 - mean_absolute_error: 0.7776 - val_loss: 12.8661 - val_mean_absolute_error: 2.3207 - 101ms/epoch - 4ms/step
# Epoch 441/500
# 26/26 - 0s - loss: 1.0163 - mean_absolute_error: 0.7240 - val_loss: 13.5518 - val_mean_absolute_error: 2.3714 - 100ms/epoch - 4ms/step
# Epoch 442/500
# 26/26 - 0s - loss: 0.9626 - mean_absolute_error: 0.6869 - val_loss: 13.5837 - val_mean_absolute_error: 2.3919 - 101ms/epoch - 4ms/step
# Epoch 443/500
# 26/26 - 0s - loss: 1.1172 - mean_absolute_error: 0.7907 - val_loss: 13.4495 - val_mean_absolute_error: 2.3551 - 174ms/epoch - 7ms/step
# Epoch 444/500
# 26/26 - 0s - loss: 0.9713 - mean_absolute_error: 0.7002 - val_loss: 13.6297 - val_mean_absolute_error: 2.3996 - 84ms/epoch - 3ms/step
# Epoch 445/500
# 26/26 - 0s - loss: 1.0546 - mean_absolute_error: 0.7458 - val_loss: 12.9306 - val_mean_absolute_error: 2.3546 - 87ms/epoch - 3ms/step
# Epoch 446/500
# 26/26 - 0s - loss: 1.0239 - mean_absolute_error: 0.7335 - val_loss: 14.0183 - val_mean_absolute_error: 2.4198 - 85ms/epoch - 3ms/step
# Epoch 447/500
# 26/26 - 0s - loss: 1.1139 - mean_absolute_error: 0.7802 - val_loss: 13.4710 - val_mean_absolute_error: 2.3619 - 87ms/epoch - 3ms/step
# Epoch 448/500
# 26/26 - 0s - loss: 1.1007 - mean_absolute_error: 0.7493 - val_loss: 12.5333 - val_mean_absolute_error: 2.2859 - 89ms/epoch - 3ms/step
# Epoch 449/500
# 26/26 - 0s - loss: 1.0465 - mean_absolute_error: 0.7233 - val_loss: 13.3794 - val_mean_absolute_error: 2.3736 - 93ms/epoch - 4ms/step
# Epoch 450/500
# 26/26 - 0s - loss: 1.0185 - mean_absolute_error: 0.7330 - val_loss: 13.5913 - val_mean_absolute_error: 2.3956 - 88ms/epoch - 3ms/step
# Epoch 451/500
# 26/26 - 0s - loss: 1.0726 - mean_absolute_error: 0.7252 - val_loss: 13.2433 - val_mean_absolute_error: 2.3409 - 87ms/epoch - 3ms/step
# Epoch 452/500
# 26/26 - 0s - loss: 1.0014 - mean_absolute_error: 0.7237 - val_loss: 13.6521 - val_mean_absolute_error: 2.3760 - 87ms/epoch - 3ms/step
# Epoch 453/500
# 26/26 - 0s - loss: 1.0940 - mean_absolute_error: 0.7635 - val_loss: 13.2093 - val_mean_absolute_error: 2.3671 - 78ms/epoch - 3ms/step
# Epoch 454/500
# 26/26 - 0s - loss: 1.0086 - mean_absolute_error: 0.7304 - val_loss: 13.1324 - val_mean_absolute_error: 2.3808 - 91ms/epoch - 4ms/step
# Epoch 455/500
# 26/26 - 0s - loss: 0.9932 - mean_absolute_error: 0.7221 - val_loss: 13.0353 - val_mean_absolute_error: 2.3392 - 98ms/epoch - 4ms/step
# Epoch 456/500
# 26/26 - 0s - loss: 1.0424 - mean_absolute_error: 0.7347 - val_loss: 13.8188 - val_mean_absolute_error: 2.3737 - 76ms/epoch - 3ms/step
# Epoch 457/500
# 26/26 - 0s - loss: 1.0887 - mean_absolute_error: 0.7495 - val_loss: 13.5437 - val_mean_absolute_error: 2.3936 - 80ms/epoch - 3ms/step
# Epoch 458/500
# 26/26 - 0s - loss: 1.2516 - mean_absolute_error: 0.8170 - val_loss: 12.6879 - val_mean_absolute_error: 2.3046 - 81ms/epoch - 3ms/step
# Epoch 459/500
# 26/26 - 0s - loss: 1.3952 - mean_absolute_error: 0.8872 - val_loss: 13.2496 - val_mean_absolute_error: 2.3542 - 93ms/epoch - 4ms/step
# Epoch 460/500
# 26/26 - 0s - loss: 1.1042 - mean_absolute_error: 0.7609 - val_loss: 12.8831 - val_mean_absolute_error: 2.3524 - 80ms/epoch - 3ms/step
# Epoch 461/500
# 26/26 - 0s - loss: 1.0755 - mean_absolute_error: 0.7230 - val_loss: 13.1422 - val_mean_absolute_error: 2.3468 - 81ms/epoch - 3ms/step
# Epoch 462/500
# 26/26 - 0s - loss: 0.9027 - mean_absolute_error: 0.6854 - val_loss: 12.7571 - val_mean_absolute_error: 2.3403 - 85ms/epoch - 3ms/step
# Epoch 463/500
# 26/26 - 0s - loss: 0.9590 - mean_absolute_error: 0.7155 - val_loss: 13.1234 - val_mean_absolute_error: 2.3755 - 86ms/epoch - 3ms/step
# Epoch 464/500
# 26/26 - 0s - loss: 1.0131 - mean_absolute_error: 0.7260 - val_loss: 13.2623 - val_mean_absolute_error: 2.3967 - 104ms/epoch - 4ms/step
# Epoch 465/500
# 26/26 - 0s - loss: 0.9495 - mean_absolute_error: 0.6978 - val_loss: 13.3626 - val_mean_absolute_error: 2.3439 - 87ms/epoch - 3ms/step
# Epoch 466/500
# 26/26 - 0s - loss: 0.8899 - mean_absolute_error: 0.6661 - val_loss: 13.4808 - val_mean_absolute_error: 2.4123 - 76ms/epoch - 3ms/step
# Epoch 467/500
# 26/26 - 0s - loss: 0.9547 - mean_absolute_error: 0.7105 - val_loss: 13.2013 - val_mean_absolute_error: 2.3490 - 92ms/epoch - 4ms/step
# Epoch 468/500
# 26/26 - 0s - loss: 0.9150 - mean_absolute_error: 0.6660 - val_loss: 12.7843 - val_mean_absolute_error: 2.3180 - 97ms/epoch - 4ms/step
# Epoch 469/500
# 26/26 - 0s - loss: 0.9599 - mean_absolute_error: 0.6829 - val_loss: 13.6007 - val_mean_absolute_error: 2.3955 - 92ms/epoch - 4ms/step
# Epoch 470/500
# 26/26 - 0s - loss: 0.9689 - mean_absolute_error: 0.6900 - val_loss: 13.0231 - val_mean_absolute_error: 2.3730 - 90ms/epoch - 3ms/step
# Epoch 471/500
# 26/26 - 0s - loss: 0.9276 - mean_absolute_error: 0.6884 - val_loss: 12.8868 - val_mean_absolute_error: 2.3680 - 93ms/epoch - 4ms/step
# Epoch 472/500
# 26/26 - 0s - loss: 0.9520 - mean_absolute_error: 0.6955 - val_loss: 14.5740 - val_mean_absolute_error: 2.5245 - 78ms/epoch - 3ms/step
# Epoch 473/500
# 26/26 - 0s - loss: 1.1723 - mean_absolute_error: 0.8208 - val_loss: 14.7710 - val_mean_absolute_error: 2.5321 - 81ms/epoch - 3ms/step
# Epoch 474/500
# 26/26 - 0s - loss: 1.1226 - mean_absolute_error: 0.7633 - val_loss: 13.0095 - val_mean_absolute_error: 2.3438 - 81ms/epoch - 3ms/step
# Epoch 475/500
# 26/26 - 0s - loss: 1.0385 - mean_absolute_error: 0.7402 - val_loss: 14.0097 - val_mean_absolute_error: 2.4545 - 99ms/epoch - 4ms/step
# Epoch 476/500
# 26/26 - 0s - loss: 1.0731 - mean_absolute_error: 0.7524 - val_loss: 13.4264 - val_mean_absolute_error: 2.3987 - 89ms/epoch - 3ms/step
# Epoch 477/500
# 26/26 - 0s - loss: 1.0066 - mean_absolute_error: 0.7272 - val_loss: 13.6767 - val_mean_absolute_error: 2.4190 - 83ms/epoch - 3ms/step
# Epoch 478/500
# 26/26 - 0s - loss: 0.8635 - mean_absolute_error: 0.6648 - val_loss: 13.9928 - val_mean_absolute_error: 2.4043 - 92ms/epoch - 4ms/step
# Epoch 479/500
# 26/26 - 0s - loss: 1.0037 - mean_absolute_error: 0.7238 - val_loss: 13.7559 - val_mean_absolute_error: 2.4079 - 90ms/epoch - 3ms/step
# Epoch 480/500
# 26/26 - 0s - loss: 1.0420 - mean_absolute_error: 0.7435 - val_loss: 14.3030 - val_mean_absolute_error: 2.5248 - 95ms/epoch - 4ms/step
# Epoch 481/500
# 26/26 - 0s - loss: 1.1025 - mean_absolute_error: 0.7810 - val_loss: 13.5669 - val_mean_absolute_error: 2.3160 - 91ms/epoch - 3ms/step
# Epoch 482/500
# 26/26 - 0s - loss: 1.1586 - mean_absolute_error: 0.7851 - val_loss: 13.8207 - val_mean_absolute_error: 2.4367 - 88ms/epoch - 3ms/step
# Epoch 483/500
# 26/26 - 0s - loss: 0.9347 - mean_absolute_error: 0.6802 - val_loss: 13.5626 - val_mean_absolute_error: 2.4213 - 94ms/epoch - 4ms/step
# Epoch 484/500
# 26/26 - 0s - loss: 0.8531 - mean_absolute_error: 0.6481 - val_loss: 13.0582 - val_mean_absolute_error: 2.3524 - 98ms/epoch - 4ms/step
# Epoch 485/500
# 26/26 - 0s - loss: 0.9515 - mean_absolute_error: 0.7031 - val_loss: 13.2243 - val_mean_absolute_error: 2.3152 - 88ms/epoch - 3ms/step
# Epoch 486/500
# 26/26 - 0s - loss: 0.9485 - mean_absolute_error: 0.7092 - val_loss: 13.2847 - val_mean_absolute_error: 2.3856 - 88ms/epoch - 3ms/step
# Epoch 487/500
# 26/26 - 0s - loss: 0.9194 - mean_absolute_error: 0.6681 - val_loss: 13.2749 - val_mean_absolute_error: 2.3105 - 98ms/epoch - 4ms/step
# Epoch 488/500
# 26/26 - 0s - loss: 0.8757 - mean_absolute_error: 0.6686 - val_loss: 12.9885 - val_mean_absolute_error: 2.3476 - 86ms/epoch - 3ms/step
# Epoch 489/500
# 26/26 - 0s - loss: 0.8375 - mean_absolute_error: 0.6449 - val_loss: 13.6965 - val_mean_absolute_error: 2.3984 - 87ms/epoch - 3ms/step
# Epoch 490/500
# 26/26 - 0s - loss: 0.8934 - mean_absolute_error: 0.6722 - val_loss: 13.6176 - val_mean_absolute_error: 2.4256 - 85ms/epoch - 3ms/step
# Epoch 491/500
# 26/26 - 0s - loss: 0.9364 - mean_absolute_error: 0.6921 - val_loss: 13.2683 - val_mean_absolute_error: 2.3761 - 86ms/epoch - 3ms/step
# Epoch 492/500
# 26/26 - 0s - loss: 1.1126 - mean_absolute_error: 0.7777 - val_loss: 13.2491 - val_mean_absolute_error: 2.3736 - 93ms/epoch - 4ms/step
# Epoch 493/500
# 26/26 - 0s - loss: 1.3099 - mean_absolute_error: 0.8680 - val_loss: 13.5212 - val_mean_absolute_error: 2.3971 - 93ms/epoch - 4ms/step
# Epoch 494/500
# 26/26 - 0s - loss: 0.9765 - mean_absolute_error: 0.7338 - val_loss: 12.5000 - val_mean_absolute_error: 2.2721 - 77ms/epoch - 3ms/step
# Epoch 495/500
# 26/26 - 0s - loss: 0.9463 - mean_absolute_error: 0.7165 - val_loss: 13.8801 - val_mean_absolute_error: 2.4355 - 95ms/epoch - 4ms/step
# Epoch 496/500
# 26/26 - 0s - loss: 0.9290 - mean_absolute_error: 0.6923 - val_loss: 12.7564 - val_mean_absolute_error: 2.2936 - 94ms/epoch - 4ms/step
# Epoch 497/500
# 26/26 - 0s - loss: 0.9287 - mean_absolute_error: 0.6918 - val_loss: 12.8200 - val_mean_absolute_error: 2.3376 - 84ms/epoch - 3ms/step
# Epoch 498/500
# 26/26 - 0s - loss: 0.9274 - mean_absolute_error: 0.7040 - val_loss: 13.8567 - val_mean_absolute_error: 2.4295 - 86ms/epoch - 3ms/step
# Epoch 499/500
# 26/26 - 0s - loss: 0.9079 - mean_absolute_error: 0.6837 - val_loss: 13.7941 - val_mean_absolute_error: 2.4265 - 109ms/epoch - 4ms/step
# Epoch 500/500
# 26/26 - 0s - loss: 0.8811 - mean_absolute_error: 0.6740 - val_loss: 13.0708 - val_mean_absolute_error: 2.3865 - 99ms/epoch - 4ms/step
